# %%
import bs4 as bs
from bs4 import BeautifulSoup
import requests
from selenium import webdriver
from selenium.webdriver.firefox.options import Options
import time
#import global_config as global_config

# %%
def navigate_page(main_url,page_url,nav_tag,nav_tag_class):
    url_s = str(page_url)
    driver = webdriver.Firefox(executable_path="geckodriver.exe")
    #r=requests.get(url_s)
    driver.get(url_s)
    page_src = driver.page_source
    s = BeautifulSoup(page_src, 'lxml')
    l=[]
    #Added bellow 3 lines to work pages which doesn't have navigation
    if(nav_tag =='NA' or nav_tag == 'na' or nav_tag_class == 'na' or nav_tag_class == 'na'):
        l.append(page_url)
        return list(l)
    for paragraph in s.find_all(str(nav_tag), class_=str(nav_tag_class)):
        #print(paragraph)
        for a in paragraph("a"):
            if "http" in a['href']:
                l.append(a['href'])
            if "http" not in a['href'] and a['href']:
                l.append(main_url+a['href'])
    driver.close()
    return l

def getproductlink(main_url,page_url,tag,tag_class,sub_tag,sub_tag_class,rt_tag,rt_class,rc_tag,rc_class):
    try:
        #data=requests.get(page_url)
        #print("Page Title is : %s" %driver.title)
        driver = webdriver.Firefox(executable_path="geckodriver.exe")
        #r=requests.get(url_s)
        driver.get(page_url)
        page_src = driver.page_source
    except Exception as error:
        driver.close()
        print('error: %s' %error)
        print("Couldn't access url at indivisual_product_links.py")

    try:
        soup = BeautifulSoup(page_src, 'lxml')
        time.sleep(2)
        driver.close()
    except Exception as error:
        driver.close()
        print("Couldn't access page source at indivisual_product_links.py")
        print(error)
    try:
        tag_l = soup.find_all(str(tag),{"class":str(tag_class)})
        st = '\n\n'.join(str(s) for s in tag_l)
        lin = BeautifulSoup(str(st),'html.parser')
        if tag_l:
            link = lin.find_all(str(sub_tag),{"class":str(sub_tag_class)})
    except:
        print("Tag/link not found. Probable tag/class-mismatch error.")
        driver.close()
    try:
        l = []
        if link:
            for i in link:
                review = []
                revt = i.find_all(str(rt_tag),{"class":str(rt_class)})
                if revt:
                    if revt[0].find('p'):
                        review.append(revt[0].find('p').text.strip())
                    else:
                        review.append(revt[0].text.strip())
                revc = i.find_all(str(rc_tag),{"class":str(rc_class)})
                if revc:
                    if revc[0].find('p'):
                        review.append(revc[0].find('p').text.strip(). rstrip('READ MORE'))
                    else:
                        review.append(revc[0].text.strip(). rstrip('READ MORE'))
                l.append(review)
                
    except Exception as error:
        print(error)
        print("Cound not find the Sub_tag/link")
        driver.close()
    #s=set(l)
    j=0
    if l:
        for i in l:
            #print(str(j)+" : "+i)
            j += 1
    return l

def getproductlinks(main_url,page_url,tag,tag_class,sub_tag,sub_tag_class,rt_tag,rt_class,rc_tag,rc_class,nav_tag,nav_tag_class):
    all_links=[]
    prev_list=[main_url]
    latest_links=navigate_page(main_url,page_url,nav_tag,nav_tag_class)
    while "https://www.snapdeal.comjavascript:void(0)" in latest_links:
            latest_links.remove("https://www.snapdeal.comjavascript:void(0)")
    while "https://www.snapdeal.comjavascript:void(0);" in latest_links:
            latest_links.remove("https://www.snapdeal.comjavascript:void(0);")
    #print(latest_links)
    repeat_cond = []
    
    while prev_list[-1]!=latest_links[-1]:
        repeat_cond = prev_list
        prev_list=latest_links
        all_links.extend(latest_links)
        latest_links=navigate_page(main_url,prev_list[-1],nav_tag,nav_tag_class)
        while "https://www.snapdeal.comjavascript:void(0)" in latest_links:
            latest_links.remove("https://www.snapdeal.comjavascript:void(0)")
        while "https://www.snapdeal.comjavascript:void(0);" in latest_links:
            latest_links.remove("https://www.snapdeal.comjavascript:void(0);")
        if latest_links == repeat_cond:
            break
        if prev_list == repeat_cond:
            break
        #print(latest_links)
        
    #print(len(all_links))
    all_links = list(set(all_links))
    print(all_links)
    
    product_links=[]
    for link in all_links:
        product_links.extend(getproductlink(main_url,link,tag,tag_class,sub_tag,sub_tag_class,rt_tag,rt_class,rc_tag,rc_class))
    return product_links

# %%
#Flipkart
main="https://www.flipkart.com"
url=str("https://www.flipkart.com/taparia-ws-05-diagonal-plier/product-reviews/itmf4fbr6npdzwvh?pid=PLIF4FBRE6KHJHXR")
tag=str("div")
tag_c=str("_1HmYoV _35HD7C col-9-12")
sub_tag_class=str("_1PBCrt")
sub_tag=str("div")
review_title_tag = "p"
review_title_class = "_2xg6Ul"
review_cont_tag = "div"
review_cont_class = "qwjRop"
nav_tag = "nav"
nav_class = "_1ypTlJ"

ans = getproductlinks(main,url,tag,tag_c,sub_tag,sub_tag_class,review_title_tag,review_title_class,review_cont_tag,review_cont_class,nav_tag,nav_class)
k = 0
for i,j in ans:
    print(k)
    k = k + 1
    print("Title = "+ i)
    print("Content = " +j)
    print(" ")

# %%
#Amazon
main="https://www.amazon.com"
#url=str("https://www.amazon.com/COOLIFE-Luggage-Expandable-Suitcase-Spinner/product-reviews/B07JJ346MH/ref=cm_cr_dp_d_show_all_top?ie=UTF8&reviewerType=all_reviews")
url=str("https://www.amazon.com/COOLIFE-Luggage-Expandable-Suitcase-Spinner/product-reviews/B07JJ346MH/ref=cm_cr_arp_d_paging_btm_27?ie=UTF8&pageNumber=27&reviewerType=all_reviews")
tag=str("div")
tag_c=str("a-section a-spacing-none reviews-content a-size-base")
sub_tag_class=str("a-section review")
sub_tag=str("div")
review_title_tag = "a"
review_title_class = "a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold"
review_cont_tag = "span"
review_cont_class = "a-size-base review-text"
nav_tag = "ul"
nav_class = "a-pagination"

ans = getproductlinks(main,url,tag,tag_c,sub_tag,sub_tag_class,review_title_tag,review_title_class,review_cont_tag,review_cont_class,nav_tag,nav_class)
k = 0
for i,j in ans:
    print(k)
    k = k + 1
    print("Title = "+ i)
    print("Content = " +j)
    print(" ")
# Out:
# ['https://www.amazon.com/COOLIFE-Luggage-Expandable-Suitcase-Spinner/product-reviews/B07JJ346MH/ref=cm_cr_arp_d_paging_btm_26?ie=UTF8&pageNumber=26&reviewerType=all_reviews', 'https://www.amazon.com/COOLIFE-Luggage-Expandable-Suitcase-Spinner/product-reviews/B07JJ346MH/ref=cm_cr_arp_d_paging_btm_28?ie=UTF8&pageNumber=28&reviewerType=all_reviews', 'https://www.amazon.com/COOLIFE-Luggage-Expandable-Suitcase-Spinner/product-reviews/B07JJ346MH/ref=cm_cr_arp_d_paging_btm_29?ie=UTF8&pageNumber=29&reviewerType=all_reviews', 'https://www.amazon.com/COOLIFE-Luggage-Expandable-Suitcase-Spinner/product-reviews/B07JJ346MH/ref=cm_cr_arp_d_paging_btm_27?ie=UTF8&pageNumber=27&reviewerType=all_reviews']
# 0
# Title = Terrific!
# Content = Nice size. Worked Gary for our trip to the Philippines. Wheels are really smooth! Really like it.
#
# 1
# Title = High quality, sleek looking, and roomy
# Content = Perfect size for a carry on item. Feels high quality and easy to use, and looks really nice.
#
# 2
# Title = Five Stars
# Content = Great for short business trips.
#
# 3
# Title = Love it!
# Content = Great when traveling for a day or two.
#
# 4
# Title = Perfect Travel Companion
# Content = Great color! Great quality. Exceeded my expectations
#
# 5
# Title = Appears to be as described
# Content = Have not use it yet. It looks correct as described .
#
# 6
# Title = Love it!
# Content = Perfect size and easy to handle!
#
# 7
# Title = Perfect size - excellent wheels - durable
# Content = Perfect size for checked bag. No noticible dings or scratches after traveling. Highly recommend.
#
# 8
# Title = Excellent design.
# Content = Sturdy but also light in weight.  I will use this baggage for an international trip.
#
# 9
# Title = Nice quality
# Content = Quick ship.  Sturdy suitcase.  Good wheels
#
# 10
# Title = Liteweight
# Content = Everything good
#
# 11
# Title = Great Quality Luggage
# Content = Fast shipping, good quality, item exactly as described
#
# 12
# Title = Is what it is
# Content = Good no frills bag. Most likely wont hold up for a serious traveler.
#
# 13
# Title = Delivery on time
# Content = Delivery was spot on and the quality of the luggage was better than expected.
#
# 14
# Title = Already used it
# Content = I've used this a handful of times so far and it works great as a carry on.
#
# 15
# Title = you get what you pay for
# Content = I do not recommend for frequent airline travel
#
# 16
# Title = Looks exactly as described. And the color is beautiful
# Content = It's as pretty as it looked in the catalog. And very sturdy. I love it
#
# 17
# Title = Solid quality and easy to handle
# Content = Excellent carry-on and sturdy!
#
# 18
# Title = awesome
# Content = love the spaciousness of it
#
# 19
# Title = 20 inch suitcase is NOT expandable!
# Content = This is the first of a few edits I presume. The rating as of now is based on first impressions and not use nor quality.The advertisement lists this suitcase as “expandable” when in fact, the one I received is NOT. That’s a huge negative as far as I’m concerned.Be back later with real word test reviews.
#
# 20
# Title = Spacious yet compact
# Content = Delivered on time and is a perfect size
#
# 21
# Title = Good quality!
# Content = Good quality suitcase. Looking forward to traveling with it!
#
# 22
# Title = Love this product - rolls so nice
# Content = Love this product - rolls so nice. doesn't fit a ton but perfect for quick weekend or short work trips. so nice
#
# 23
# Title = good
# Content = lots of space and compartments. high quality materials
#
# 24
# Title = Love the color
# Content = Nice light suitcase. Great color
#
# 25
# Title = buena maleta
# Content = todfo bien
#
# 26
# Title = It was just what I was look for
# Content = It was just what I was look for
#
# 27
# Title = I Loved it
# Content = It's beautiful!
#
# 28
# Title = Very good choice
# Content = What an awesome product!
#
# 29
# Title = Works very well
# Content = My new suitcase is great. The wheels make it so easy to handle, and I like the sturdy case.
#
# 30
# Title = I love it!
# Content = Very nice. Lightweight and roomy.
#
# 31
# Title = Light and EASY to roll.
# Content = It is very light and moves very easy. Best luggage I’ve ever had.

# %%
#Snapdeal
main="https://www.snapdeal.com"
#url=str("https://www.snapdeal.com/product/nike-epic-react-flyknit-silver/684460913725/reviews?&sortBy=HELPFUL#defRevPDP")
url="https://www.snapdeal.com/product/nike-epic-react-flyknit-silver/684460913725/reviews?page=10&sortBy=HELPFUL#defRevPDP"
tag=str("div")
tag_c=str("reviewareain clearfix")
sub_tag_class=str("commentlist first jsUserAction")
sub_tag=str("div")
review_title_tag = "div"
review_title_class = "head"
review_cont_tag = "p"
review_cont_class = ""
nav_tag = "ul"
nav_class = "LTblack"



ans = getproductlinks(main,url,tag,tag_c,sub_tag,sub_tag_class,review_title_tag,review_title_class,review_cont_tag,review_cont_class,nav_tag,nav_class)
k = 0
for i,j in ans:
    print(k)
    k = k + 1
    print("Title = "+ i)
    print("Content = " +j)
    print(" ")
