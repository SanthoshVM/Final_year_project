# %%
import bs4 as bs
from bs4 import BeautifulSoup
import requests
from selenium import webdriver
from selenium.webdriver.firefox.options import Options
import time
#import global_config as global_config

# %%
def navigate_page(main_url,page_url,nav_tag,nav_tag_class):
    url_s = str(page_url)
    driver = webdriver.Firefox(executable_path="geckodriver.exe")
    #r=requests.get(url_s)
    driver.get(url_s)
    page_src = driver.page_source
    s = BeautifulSoup(page_src, 'lxml')
    l=[]
    #Added bellow 3 lines to work pages which doesn't have navigation
    if(nav_tag =='NA' or nav_tag == 'na' or nav_tag_class == 'na' or nav_tag_class == 'na'):
        l.append(page_url)
        return list(l)
    for paragraph in s.find_all(str(nav_tag), class_=str(nav_tag_class)):
        #print(paragraph)
        for a in paragraph("a"):
            if "http" in a['href']:
                l.append(a['href'])
            if "http" not in a['href'] and a['href']:
                l.append(main_url+a['href'])
    driver.close()
    return l

def getproductlink(main_url,page_url,tag,tag_class,sub_tag,sub_tag_class,rt_tag,rt_class,rc_tag,rc_class):
    try:
        #data=requests.get(page_url)
        #print("Page Title is : %s" %driver.title)
        driver = webdriver.Firefox(executable_path="geckodriver.exe")
        #r=requests.get(url_s)
        driver.get(page_url)
        page_src = driver.page_source
    except Exception as error:
        driver.close()
        print('error: %s' %error)
        print("Couldn't access url at indivisual_product_links.py")

    try:
        soup = BeautifulSoup(page_src, 'lxml')
        time.sleep(2)
        driver.close()
    except Exception as error:
        driver.close()
        print("Couldn't access page source at indivisual_product_links.py")
        print(error)
    try:
        tag_l = soup.find_all(str(tag),{"class":str(tag_class)})
        st = '\n\n'.join(str(s) for s in tag_l)
        lin = BeautifulSoup(str(st),'html.parser')
        if tag_l:
            link = lin.find_all(str(sub_tag),{"class":str(sub_tag_class)})
    except:
        print("Tag/link not found. Probable tag/class-mismatch error.")
        driver.close()
    try:
        l = []
        if link:
            for i in link:
                review = []
                revt = i.find_all(str(rt_tag),{"class":str(rt_class)})
                if revt:
                    if revt[0].find('p'):
                        review.append(revt[0].find('p').text.strip())
                    else:
                        review.append(revt[0].text.strip())
                revc = i.find_all(str(rc_tag),{"class":str(rc_class)})
                if revc:
                    if revc[0].find('p'):
                        review.append(revc[0].find('p').text.strip(). rstrip('READ MORE'))
                    else:
                        review.append(revc[0].text.strip(). rstrip('READ MORE'))
                l.append(review)
                
    except Exception as error:
        print(error)
        print("Cound not find the Sub_tag/link")
        driver.close()
    #s=set(l)
    j=0
    if l:
        for i in l:
            #print(str(j)+" : "+i)
            j += 1
    return l

def getproductlinks(main_url,page_url,tag,tag_class,sub_tag,sub_tag_class,rt_tag,rt_class,rc_tag,rc_class,nav_tag,nav_tag_class):
    all_links=[]
    prev_list=[main_url]
    latest_links=navigate_page(main_url,page_url,nav_tag,nav_tag_class)
    while "https://www.snapdeal.comjavascript:void(0)" in latest_links:
            latest_links.remove("https://www.snapdeal.comjavascript:void(0)")
    while "https://www.snapdeal.comjavascript:void(0);" in latest_links:
            latest_links.remove("https://www.snapdeal.comjavascript:void(0);")
    #print(latest_links)
    repeat_cond = []
    
    while prev_list[-1]!=latest_links[-1]:
        repeat_cond = prev_list
        prev_list=latest_links
        all_links.extend(latest_links)
        latest_links=navigate_page(main_url,prev_list[-1],nav_tag,nav_tag_class)
        while "https://www.snapdeal.comjavascript:void(0)" in latest_links:
            latest_links.remove("https://www.snapdeal.comjavascript:void(0)")
        while "https://www.snapdeal.comjavascript:void(0);" in latest_links:
            latest_links.remove("https://www.snapdeal.comjavascript:void(0);")
        if latest_links == repeat_cond:
            break
        if prev_list == repeat_cond:
            break
        #print(latest_links)
        
    #print(len(all_links))
    all_links = list(set(all_links))
    print(all_links)
    
    product_links=[]
    for link in all_links:
        product_links.extend(getproductlink(main_url,link,tag,tag_class,sub_tag,sub_tag_class,rt_tag,rt_class,rc_tag,rc_class))
    return product_links

# %%
#Flipkart
main="https://www.flipkart.com"
url=str("https://www.flipkart.com/taparia-ws-05-diagonal-plier/product-reviews/itmf4fbr6npdzwvh?pid=PLIF4FBRE6KHJHXR")
tag=str("div")
tag_c=str("_1HmYoV _35HD7C col-9-12")
sub_tag_class=str("_1PBCrt")
sub_tag=str("div")
review_title_tag = "p"
review_title_class = "_2xg6Ul"
review_cont_tag = "div"
review_cont_class = "qwjRop"
nav_tag = "nav"
nav_class = "_1ypTlJ"

ans = getproductlinks(main,url,tag,tag_c,sub_tag,sub_tag_class,review_title_tag,review_title_class,review_cont_tag,review_cont_class,nav_tag,nav_class)
k = 0
for i,j in ans:
    print(k)
    k = k + 1
    print("Title = "+ i)
    print("Content = " +j)
    print(" ")
# Out:
# ['https://www.flipkart.com/taparia-ws-05-diagonal-plier/product-reviews/itmf4fbr6npdzwvh?pid=PLIF4FBRE6KHJHXR&page=2', 'https://www.flipkart.com/taparia-ws-05-diagonal-plier/product-reviews/itmf4fbr6npdzwvh?pid=PLIF4FBRE6KHJHXR&page=4', 'https://www.flipkart.com/taparia-ws-05-diagonal-plier/product-reviews/itmf4fbr6npdzwvh?pid=PLIF4FBRE6KHJHXR&page=6', 'https://www.flipkart.com/taparia-ws-05-diagonal-plier/product-reviews/itmf4fbr6npdzwvh?pid=PLIF4FBRE6KHJHXR&page=7', 'https://www.flipkart.com/taparia-ws-05-diagonal-plier/product-reviews/itmf4fbr6npdzwvh?pid=PLIF4FBRE6KHJHXR&page=5', 'https://www.flipkart.com/taparia-ws-05-diagonal-plier/product-reviews/itmf4fbr6npdzwvh?pid=PLIF4FBRE6KHJHXR&page=3', 'https://www.flipkart.com/taparia-ws-05-diagonal-plier/product-reviews/itmf4fbr6npdzwvh?pid=PLIF4FBRE6KHJHXR&page=1']
# 0
# Title = Moderate
# Content = prise high
#
# 1
# Title = Must buy!
# Content = Fantastic quality
#
# 2
# Title = Pretty good
# Content = perfect
#
# 3
# Title = Terrific purchase
# Content = awesome tools
#
# 4
# Title = Delightful
# Content = good and  worthful
#
# 5
# Title = Classy product
# Content = good
#
# 6
# Title = Fabulous!
# Content = best product best quality
#
# 7
# Title = Excellent Product
# Content = Very good Quality ItemVery Fast delivery Flipkart
#
# 8
# Title = Moderate
# Content = worst product... I got for 49/-...product has  issue's.
#
# 9
# Title = Delightful
# Content = best quality only 49 rupess
#
# 10
# Title = Absolute rubbish!
# Content = Quality not good for rough use
#
# 11
# Title = Does the job
# Content = Good quality product
#
# 12
# Title = Wonderful
# Content = taparia is the best.
#
# 13
# Title = Mind-blowing purchase
# Content = very good
#
# 14
# Title = Worth every penny
# Content = nice
#
# 15
# Title = Must buy!
# Content = thanks
#
# 16
# Title = Super!
# Content = Very good
#
# 17
# Title = Super!
# Content = Very nice
#
# 18
# Title = Really Nice
# Content = nice product
#
# 19
# Title = Perfect product!
# Content = nice
#
# 20
# Title = Fabulous!
# Content = Awesome 👌 product
#
# 21
# Title = Just wow!
# Content = ameging
#
# 22
# Title = Could be way better
# Content = not bat
#
# 23
# Title = Mind-blowing purchase
# Content = Small in size & easy to use. .......
#
# 24
# Title = Fair
# Content = amazing great product
#
# 25
# Title = Delightful
# Content = good
#
# 26
# Title = Fabulous!
# Content = Good quality nice product
#
# 27
# Title = Terrific purchase
# Content = goodone
#
# 28
# Title = Awesome
# Content = Super
#
# 29
# Title = Awesome
# Content = awesome product thanks Flipkart value for money product
#
# 30
# Title = Nice
# Content = Not bad
#
# 31
# Title = Fabulous!
# Content = product are awsomeQuilty good
#
# 32
# Title = Brilliant
# Content = very good.original taparia product
#
# 33
# Title = Awesome
# Content = super
#
# 34
# Title = Pretty good
# Content = Good
#
# 35
# Title = Terrific purchase
# Content = nice product
#
# 36
# Title = Not recommended at all
# Content = Average quality and Rate is high.
#
# 37
# Title = Really Nice
# Content = very nice
#
# 38
# Title = Classy product
# Content = excellent product
#
# 39
# Title = Nice
# Content = good
#
# 40
# Title = Simply awesome
# Content = thanks for taparia & standard quality, delivery boy is too good. 😊😊
#
# 41
# Title = Great product
# Content = wery wery NAIC product
#
# 42
# Title = Perfect product!
# Content = quality is very good
#
# 43
# Title = Good
# Content = nothing special, just ok product
#
# 44
# Title = Classy product
# Content = good
#
# 45
# Title = Good
# Content = ok
#
# 46
# Title = Best in the market!
# Content = very happy to have this unique product
#
# 47
# Title = Worth every penny
# Content = Happy with the price and quality of the product.
#
# 48
# Title = Highly recommended
# Content = nice
#
# 49
# Title = Simply awesome
# Content = very very good prodact...
#
# 50
# Title = Excellent
# Content = Nice one
#
# 51
# Title = Worth every penny
# Content = super
#
# 52
# Title = Delightful
# Content = material is good
#
# 53
# Title = Fabulous!
# Content = super
#
# 54
# Title = Brilliant
# Content = Very Important Tools.
#
# 55
# Title = Very Good
# Content = his mrp is 57 rupees good i bought in 54 rupees good product....than others
#
# 56
# Title = Terrific
# Content = very nice quality
#
# 57
# Title = Must buy!
# Content = wonderful.... Best product...
#
# 58
# Title = Very Good
# Content = good
#
# 59
# Title = Excellent
# Content = nice very nice
#
# 60
# Title = Great product
# Content = good quality.... got genuine product
#
# 61
# Title = Classy product
# Content = ok
#
# 62
# Title = Mind-blowing purchase
# Content = very very good product
#
# 63
# Title = Simply awesome
# Content = very good product.. I am from assam..
#
# 64
# Title = Terrific
# Content = good product

# %%
#Amazon
main="https://www.amazon.com"
#url=str("https://www.amazon.com/COOLIFE-Luggage-Expandable-Suitcase-Spinner/product-reviews/B07JJ346MH/ref=cm_cr_dp_d_show_all_top?ie=UTF8&reviewerType=all_reviews")
url=str("https://www.amazon.com/COOLIFE-Luggage-Expandable-Suitcase-Spinner/product-reviews/B07JJ346MH/ref=cm_cr_getr_d_paging_btm_prev_32?ie=UTF8&pageNumber=32&reviewerType=all_reviews")
tag=str("div")
tag_c=str("a-section a-spacing-none reviews-content a-size-base")
sub_tag_class=str("a-section review aok-relative")
sub_tag=str("div")
review_title_tag = "a"
review_title_class = "a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold"
review_cont_tag = "span"
review_cont_class = "a-size-base review-text"
nav_tag = "ul"
nav_class = "a-pagination"

ans = getproductlinks(main,url,tag,tag_c,sub_tag,sub_tag_class,review_title_tag,review_title_class,review_cont_tag,review_cont_class,nav_tag,nav_class)
print("----")
print(ans)
k = 0
for i,j in ans:
    print(k)
    k = k + 1
    print("Title = "+ i)
    print("Content = " +j)
    print(" ")
# Out:
# ['https://www.amazon.com/COOLIFE-Luggage-Expandable-Suitcase-Spinner/product-reviews/B07JJ346MH/ref=cm_cr_arp_d_paging_btm_33?ie=UTF8&pageNumber=33&reviewerType=all_reviews', 'https://www.amazon.com/COOLIFE-Luggage-Expandable-Suitcase-Spinner/product-reviews/B07JJ346MH/ref=cm_cr_arp_d_paging_btm_32?ie=UTF8&pageNumber=32&reviewerType=all_reviews', 'https://www.amazon.com/COOLIFE-Luggage-Expandable-Suitcase-Spinner/product-reviews/B07JJ346MH/ref=cm_cr_arp_d_paging_btm_31?ie=UTF8&pageNumber=31&reviewerType=all_reviews']
# ----
# []

# %%
#Snapdeal
main="https://www.snapdeal.com"
#url=str("https://www.snapdeal.com/product/nike-epic-react-flyknit-silver/684460913725/reviews?&sortBy=HELPFUL#defRevPDP")
url="https://www.snapdeal.com/product/nike-epic-react-flyknit-silver/684460913725/reviews?page=10&sortBy=HELPFUL#defRevPDP"
tag=str("div")
tag_c=str("reviewareain clearfix")
sub_tag_class=str("commentlist first jsUserAction")
sub_tag=str("div")
review_title_tag = "div"
review_title_class = "head"
review_cont_tag = "p"
review_cont_class = ""
nav_tag = "ul"
nav_class = "LTblack"



ans = getproductlinks(main,url,tag,tag_c,sub_tag,sub_tag_class,review_title_tag,review_title_class,review_cont_tag,review_cont_class,nav_tag,nav_class)
k = 0
for i,j in ans:
    print(k)
    k = k + 1
    print("Title = "+ i)
    print("Content = " +j)
    print(" ")
# Out:
# ['https://www.snapdeal.com/product/nike-epic-react-flyknit-silver/684460913725/reviews?&sortBy=HELPFUL#defRevPDP', 'https://www.snapdeal.com/product/nike-epic-react-flyknit-silver/684460913725/reviews?page=13&sortBy=HELPFUL#defRevPDP', 'https://www.snapdeal.com/product/nike-epic-react-flyknit-silver/684460913725/reviews?page=14&sortBy=HELPFUL#defRevPDP', 'https://www.snapdeal.com/product/nike-epic-react-flyknit-silver/684460913725/reviews?page=9&sortBy=HELPFUL#defRevPDP', 'https://www.snapdeal.com/product/nike-epic-react-flyknit-silver/684460913725/reviews?page=12&sortBy=HELPFUL#defRevPDP', 'https://www.snapdeal.com/product/nike-epic-react-flyknit-silver/684460913725/reviews?page=10&sortBy=HELPFUL#defRevPDP', 'https://www.snapdeal.com/product/nike-epic-react-flyknit-silver/684460913725/reviews?page=11&sortBy=HELPFUL#defRevPDP', 'https://www.snapdeal.com/product/nike-epic-react-flyknit-silver/684460913725/reviews?page=15&sortBy=HELPFUL#defRevPDP']
# 0
# Title = Good quality...
# Content = Nice product.....
#
# 1
# Title = Best shoes for running
# Content = Perfect for running
#
# 2
# Title = Best Product
# Content = Comfortable
#
# 3
# Title = Shoes
# Content = Nice shoes
#
# 4
# Title = fabulous
# Content = good product
#
# 5
# Title = I like it
# Content = shoe is so nice
#
# 6
# Title = Fantastic
# Content = Its Awesome.
#
# 7
# Title = Good quality
# Content = Worth to buy
#
# 8
# Title = Suprrrrr
# Content = Good to wear
#
# 9
# Title = Nike rocks
# Content = Fantabulous
#
# 10
# Title = A good purchase
# Content = Nice shoes.....good quality.
#
# 11
# Title = Good nice
# Content = Wonderfull
#
# 12
# Title = Decent
# Content = Decent quality as expected.
#
# 13
# Title = Nike running shoes
# Content = Good performance
#
# 14
# Title = Nice one
# Content = Very comfortable shoes.
#
# 15
# Title = According to price not good.
# Content = In this price i bought good shoes like this.
#
# 16
# Title = Very happy
# Content = Very nice produk
# Good
#
# 17
# Title = Though it's a copy. But, its worth investing in.
# Content = Very Comfortable & Light weight. I hope they last long.
#
# 18
# Title = Quality is not so good
# Content = Shole is good comfortable but the quality ofupper front  part of shoes is not as expected
#
# 19
# Title = sole is not much comfirt for running
# Content = sole is not much comfirt for running
#
# 20
# Title = Not satisfy
# Content = Size is small
#
# 21
# Title = Not to bad
# Content = Shoes quality is good but not I expect nicely build and good fabric
#
# 22
# Title = Nike shoes
# Content = Does not look like
#    Is almost right on
#
# 23
# Title = Average marks for product
# Content = Rajdhani express delivery and not a original product but rate vise okk...
#
# 24
# Title = Bad product
# Content = Not good. Product, not happy
#
# 25
# Title = Not good
# Content = Not good, bad quality
#
# 26
# Title = Two Stars
# Content = No perfect  only time pass
#
# 27
# Title = DONT BUY IT. I RECIEVED FAKE SHOES
# Content = Just are 1st copy of nike epic react
#
# 28
# Title = no good
# Content = No good no good
#
# 29
# Title = Nike epic react
# Content = Too poor product
#
# 30
# Title = nike shoe
# Content = i m pleased with this product
#
# 31
# Title = Original
# Content = Very nice product,,really good
#
# 32
# Title = Good Quality
# Content = Happy with product
#
# 33
# Title = Great product
# Content = Best pair of shoes I have ever purchased
#
# 34
# Title = Light weight
# Content = Nice and good looking
#
# 35
# Title = VERY good
# Content = Proper time delivery and bank right time
#
# 36
# Title = I am satisfying to ur product ND services
# Content = Good servicr
#
# 37
# Title = Nice product
# Content = Value for monet paisa wasool product
#
# 38
# Title = Excellent
# Content = Awesome excellent what else, best at this price range, thanks Snapdeal
#
# 39
# Title = Good product
# Content = Light weight , nice fitting , super fast delivery..
#
# 40
# Title = Purse
# Content = Quality very good
#
# 41
# Title = Suprb
# Content = Good service
#
# 42
# Title = Sports shoes
# Content = Nice Sports shoes
#
# 43
# Title = Delivery is good
# Content = This shoes are awesome
#
# 44
# Title = H......
# Content = Nice and original shoes
#
# 45
# Title = Love it
# Content = Nyc shoes nd very comfortable i like it tnxx Snapdeal
#
# 46
# Title = goods
# Content = ok good good
#
# 47
# Title = Good job and good quality
# Content = Quality is gd and delivery is v gd
#
# 48
# Title = Nice shoes and perfect delivery.
# Content = Superb experience.
#
# 49
# Title = Nike flyknit react
# Content = Good value for the price. Slightly stiff soles but no complaints
#
# 50
# Title = Asom godd
# Content = Good shoes and it is original one
#
# 51
# Title = Good..
# Content = This good product for value
#
# 52
# Title = Nice shoe , original and are very comfortable.
# Content = They are original and are very comfortable. The comments that are saying that they are fake are wrong. I got an origi and piece
#
# 53
# Title = Five Stars
# Content = Very nice shoes & fast delivery
#
# 54
# Title = Nic nd good
# Content = Good item and nic shoes
#
# 55
# Title = Nice shoe
# Content = Super shoe very nice quality
#
# 56
# Title = Very goid
# Content = Very good shooe
#
# 57
# Title = stylish and lightweight
# Content = looking nice
#
# 58
# Title = nice pair of nike
# Content = Looks nice but trend for all net shows worries about its early torn
#
# 59
# Title = Good stuff
# Content = Good original product
# I like it
#
# 60
# Title = Its nice & wonderful shoes
# Content = Gooooood & superbly
#
# 61
# Title = Nike shoes
# Content = Ratwise item is good
#
# 62
# Title = Four Stars
# Content = Good Nike shoes on affordable rates 2k and good delivery,
#
# 63
# Title = Good Product
# Content = Product is very comfortable
#
# 64
# Title = Perfect delivery
# Content = I am satisfied
#
# 65
# Title = A different product which can give a new look n personality .
# Content = Superb product. A new type laces fitted. Light ,comfort and stylish..
#
# 66
# Title = Four Stars
# Content = Very good product
#
# 67
# Title = V Nice
# Content = Comfortable
#
# 68
# Title = Nice n flexible
# Content = Nice and flexible and easy
#
# 69
# Title = Nice shoes
# Content = Good quality
#
# 70
# Title = True copy not genuine product
# Content = It is not a genuine item.
